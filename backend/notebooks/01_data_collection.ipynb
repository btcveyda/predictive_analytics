# %% [markdown]
# # Data Collection and Inspection
#
# Load the California Housing dataset, save it to CSV, and inspect the raw data.

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing(as_frame=True)
df = housing.frame
df.to_csv('../app/data/housing.csv', index=False)
df.head()

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %% [markdown]
# ## Cleaning Notes
#
# The California Housing dataset is already well-structured, but we still validate duplicates and missing values before analysis.
